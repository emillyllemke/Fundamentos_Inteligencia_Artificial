# %% [markdown]
# <a href="https://colab.research.google.com/github/emillyllemke/Fundamentos_Inteligencia_Artificial/blob/main/Aula_Intelig%C3%AAncia_Artificial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #AULA DE INTELIGÊNCIA ARTIFICIAL - 06/03/2026

# %%
print("Olá Mundo")
